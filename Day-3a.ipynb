# %%
# %pip install google-adk
# Out:
# Requirement already satisfied: google-adk in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.71.2)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: greenlet>=1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: Mako in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GEMINI_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("Please set the GOOGLE_API_KEY environment variable.")

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
print("✅Google API Key is set successfully.")
# Out:
# ✅Google API Key is set successfully.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base = 7,
    initial_delay=1,
    http_status_codes=[429,500,503,504]
)

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %%
await run_session(
    runner,
    [
        "Hi, I am Snehal! What is the capital of India?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Snehal! What is the capital of India?
# gemini-2.5-flash-lite >  Hi Snehal! The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  You told me your name is Snehal.

# %%
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  Earlier, you asked me about the capital of India.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Snehal.

# %%
chat_bot = LlmAgent(
    name="text_chat_bot",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="A text chatbot with persistent memory",
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chat_bot, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %%
await run_session(
    runner,
    ["Hi, I am Snehal! What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
#  ### Session: test-db-session-01
#
# User > Hi, I am Snehal! What is the capital of India?
# gemini-2.5-flash-lite >  Hi Snehal! The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Snehal.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Snehal.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, so I do not know your name.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[52], line 14
#      10         for each in result.fetchall():
#      11             print(each)
# ---> 14 check_data_in_db()
#
# Cell In[52], line 6, in check_data_in_db()
#       4 with sqlite3.connect("my_agent_data.db") as connection:
#       5     cursor = connection.cursor()
# ----> 6     result = cursor.execute(
#       7         "select app_name, session_id, author, content from events"
#       8     )
#       9     print([_[0] for _ in result.description])
#      10     for each in result.fetchall():
#
# OperationalError: no such table: events

# %%
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chat_bot,
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  
        overlap_size=1, 
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)

print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_68533/3562575673.py:4: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  The field of AI in healthcare is advancing rapidly, with new developments emerging constantly. Here's a summary of some of the latest and most significant trends and news:
#
# **1. Generative AI and Large Language Models (LLMs) for Clinical Applications:**
#
# *   **Accelerated Drug Discovery and Development:** Companies are using AI, particularly LLMs, to analyze vast biological datasets, predict molecular interactions, and identify potential drug candidates much faster than traditional methods. This includes designing novel proteins and optimizing drug formulations.
# *   **Clinical Documentation and Administrative Tasks:** LLMs are being integrated to automate tasks like summarizing patient notes, generating draft reports, responding to patient inquiries, and streamlining billing and coding processes. This aims to reduce physician burnout and improve efficiency.
# *   **Personalized Treatment Plans:** AI is being used to analyze a patient's genetic information, medical history, and lifestyle data to recommend the most effective and personalized treatment strategies, especially in areas like oncology.
# *   **Medical Education and Training:** LLMs are being developed as AI tutors and simulators to help train medical students and professionals, offering interactive learning experiences and answering complex medical questions.
#
# **2. AI for Diagnostics and Imaging:**
#
# *   **Enhanced Medical Image Analysis:** AI algorithms are becoming increasingly sophisticated in detecting subtle anomalies in X-rays, CT scans, MRIs, and pathology slides, often with greater accuracy and speed than human interpretation alone. This is particularly impactful in early cancer detection and identifying neurological conditions.
# *   **Predictive Diagnostics:** AI models are being trained to predict the likelihood of a patient developing certain diseases based on their health records and other data, allowing for earlier intervention and preventative care.
# *   **Digital Pathology:** AI is revolutionizing pathology by automating the analysis of tissue samples, improving diagnostic consistency, and identifying patterns invisible to the human eye.
#
# **3. AI in Patient Care and Monitoring:**
#
# *   **Remote Patient Monitoring:** Wearable devices and AI are enabling continuous monitoring of vital signs and other health parameters for patients with chronic conditions, allowing for early detection of deterioration and timely intervention.
# *   **Virtual Health Assistants and Chatbots:** AI-powered chatbots are providing patients with 24/7 access to health information, appointment scheduling, medication reminders, and even initial symptom assessment, improving patient engagement and access to care.
# *   **Mental Health Support:** AI is being explored for early detection of mental health issues through analyzing speech patterns, text, and even facial expressions, and for providing accessible therapeutic support through AI-powered platforms.
#
# **4. Regulatory and Ethical Considerations:**
#
# *   **FDA Approvals:** The U.S. Food and Drug Administration (FDA) is actively reviewing and approving AI-powered medical devices and software. The number of AI/ML-enabled medical device approvals has been steadily increasing.
# *   **Data Privacy and Security:** With the increasing use of sensitive patient data, robust data privacy and security measures are paramount. Regulations like HIPAA are being adapted to address AI-specific challenges.
# *   **Bias and Equity:** Ensuring AI algorithms are fair and do not perpetuate existing healthcare disparities is a major focus. Efforts are underway to identify and mitigate biases in training data and algorithm development.
# *   **Explainability and Trust:** Developing AI models that can explain their reasoning (explainable AI or XAI) is crucial for building trust among clinicians and patients, allowing them to understand and validate AI-driven recommendations.
#
# **5. Key Players and Innovations:**
#
# *   **Major Tech Companies:** Google Health, Microsoft Healthcare, Amazon Web Services (AWS), and IBM are heavily investing in AI for healthcare, developing platforms and solutions for various medical applications.
# *   **Biotech and Pharma:** Companies like Moderna, Pfizer, and numerous smaller biotechs are leveraging AI for drug discovery and clinical trial optimization.
# *   **Startups:** A vibrant ecosystem of startups is emerging, focusing on niche areas like AI-powered radiology, personalized medicine, and virtual care.
#
# **Challenges and the Road Ahead:**
#
# Despite the rapid progress, challenges remain, including:
#
# *   **Data availability and quality:** Access to diverse, high-quality, and representative datasets is crucial for training robust AI models.
# *   **Integration into existing workflows:** Seamlessly integrating AI tools into clinical practice requires careful planning, training, and change management.
# *   **Cost and scalability:** The cost of developing and deploying AI solutions can be significant, and scaling them across healthcare systems is a hurdle.
# *   **Physician and patient adoption:** Building confidence and acceptance among healthcare professionals and patients is essential for widespread adoption.
#
# Overall, AI in healthcare is moving beyond research and development into real-world applications that have the potential to transform how diseases are diagnosed, treated, and prevented, while also improving the efficiency and accessibility of healthcare services. It's a dynamic space to watch!
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, absolutely! Drug discovery is one of the most dynamic and impactful areas for AI in healthcare. The latest developments are truly exciting and are accelerating the process in several key ways:
#
# **1. Generative AI and LLMs for Novel Molecule Design:**
#
# *   **De Novo Drug Design:** This is a major breakthrough. Instead of screening existing libraries of compounds, generative AI models (like those based on GANs, VAEs, or diffusion models) can now *create* entirely new molecular structures from scratch that are predicted to have specific desired properties. This includes designing molecules that bind to target proteins, have favorable pharmacokinetic profiles (how the body absorbs, distributes, metabolizes, and excretes a drug), and minimize toxicity.
# *   **Optimizing Existing Leads:** AI can take a promising but imperfect drug candidate and suggest modifications to improve its efficacy, safety, or deliverability.
# *   **Targeted Library Generation:** Instead of creating vast, unfocused libraries, AI can design focused libraries of compounds specifically tailored to a particular disease target or pathway.
#
# **2. AI for Target Identification and Validation:**
#
# *   **Uncovering New Disease Drivers:** AI can analyze massive amounts of genomic, proteomic, transcriptomic, and clinical data to identify novel biological targets that play a critical role in disease progression. This helps researchers understand the underlying mechanisms of disease and find new points of intervention.
# *   **Predicting Target Tractability:** AI models are being developed to predict whether a newly identified target is "druggable," meaning if it's feasible to develop a molecule that can effectively interact with it.
#
# **3. Revolutionizing Preclinical Research:**
#
# *   **Predicting ADMET Properties:** AI is significantly improving the prediction of Absorption, Distribution, Metabolism, Excretion, and Toxicity (ADMET) properties of drug candidates much earlier in the discovery process. This helps eliminate compounds with poor pharmacokinetic profiles or toxicity concerns before costly and time-consuming lab experiments.
# *   **Virtual Screening Enhancements:** While virtual screening isn't new, AI is making it much more powerful. Deep learning models can learn complex relationships between molecular structures and their biological activity, leading to more accurate and efficient identification of potential hits from large compound databases.
# *   **In Silico Trial Design:** AI is being used to design and simulate preclinical experiments, reducing the need for some animal testing and optimizing experimental parameters.
#
# **4. Accelerating Clinical Trials (though this is downstream of discovery, it's closely linked):**
#
# *   **Patient Stratification:** AI can help identify patient subgroups who are most likely to respond to a particular drug, leading to more successful and efficient clinical trials.
# *   **Predicting Clinical Trial Outcomes:** AI models are being developed to predict the likelihood of success for a given drug candidate in clinical trials, helping companies prioritize their investments.
#
# **5. Specific Examples and Companies:**
#
# Many companies are at the forefront of these advancements. Here are a few examples of the types of work being done:
#
# *   **Insilico Medicine:** Known for its end-to-end AI-driven drug discovery platform, they've made headlines for moving AI-discovered and designed drugs into clinical trials rapidly.
# *   **Exscientia:** This company uses AI to identify novel drug targets and design drug candidates, and has partnered with major pharmaceutical companies.
# *   **Atomwise:** Utilizes deep learning for structure-based drug discovery and virtual screening.
# *   **Recursion Pharmaceuticals:** Employs AI and machine learning on vast biological datasets to discover new drug targets and therapies.
# *   **Relay Therapeutics:** Focuses on protein motion and uses computational methods, including AI, to understand how drugs bind to their targets.
#
# **The Impact:**
#
# The overall impact of these AI developments in drug discovery is:
#
# *   **Speed:** Significantly reducing the time it takes to move from initial concept to preclinical candidate.
# *   **Cost Reduction:** Eliminating less promising candidates earlier and optimizing experimental processes.
# *   **Novelty:** Discovering entirely new types of molecules and identifying previously unknown therapeutic targets.
# *   **Increased Success Rates:** By making more informed decisions at each stage, AI aims to improve the overall success rate of drug development.
#
# It's important to note that while AI is a powerful tool, it's still a tool. Human expertise and validation remain critical throughout the drug discovery process. However, AI is undoubtedly a game-changer, ushering in a new era of more efficient and innovative drug development.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're likely referring to the second development I mentioned: **AI for Target Identification and Validation.** This is a crucial early step in drug discovery, and AI is making significant inroads here.
#
# Let's break it down further:
#
# **What is Target Identification and Validation?**
#
# *   **Target Identification:** This is the process of finding a specific molecule (usually a protein, but can also be a gene or other biological entity) in the body that is implicated in a disease. The idea is that by modulating this target (e.g., inhibiting an overactive enzyme, activating a deficient receptor), we can treat or prevent the disease.
# *   **Target Validation:** Once a potential target is identified, it needs to be "validated." This means providing strong evidence that the target is indeed involved in the disease and that modulating it will have a therapeutic benefit without causing unacceptable side effects.
#
# **How is AI Revolutionizing This Process?**
#
# Traditionally, target identification and validation relied heavily on laborious lab experiments, hypothesis-driven research, and serendipity. AI is changing this by enabling:
#
# 1.  **Analysis of Massive, Multi-Omics Datasets:**
#     *   **What's available?** We now have access to enormous datasets from various "omics" technologies:
#         *   **Genomics:** DNA sequences of individuals and populations.
#         *   **Transcriptomics:** Gene expression levels (which genes are active).
#         *   **Proteomics:** Protein levels and modifications.
#         *   **Metabolomics:** Levels of small molecules (metabolites).
#         *   **Clinical Data:** Patient records, electronic health records (EHRs), imaging data, patient-reported outcomes.
#     *   **AI's Role:** AI algorithms, particularly machine learning and deep learning, are adept at sifting through these complex, high-dimensional datasets to find subtle patterns and correlations that human researchers might miss. They can identify genes or proteins that are consistently dysregulated in diseased states compared to healthy individuals.
#
# 2.  **Uncovering Novel Disease Mechanisms and Pathways:**
#     *   **Beyond Simple Correlations:** AI can go beyond just identifying which genes are "up" or "down" in a disease. It can help infer complex biological pathways and networks. For example, it might identify a chain of protein interactions that leads to a disease phenotype.
#     *   **Systems Biology Approach:** AI facilitates a "systems biology" approach, where the focus is on how different biological components interact as a whole, rather than just studying individual molecules in isolation.
#
# 3.  **Predicting "Druggability" and Tractability:**
#     *   **Is it a good target for a drug?** Not all disease-relevant molecules are good drug targets. Some are hard to access with drugs, some might cause too many side effects if modulated, and some may not have a clear mechanism for therapeutic intervention.
#     *   **AI's Predictive Power:** AI models can be trained on historical data of successful and unsuccessful drug targets to predict the likelihood that a newly identified target can be effectively modulated by a drug. This includes factors like:
#         *   **Structural Properties:** Is the protein amenable to binding small molecules or antibodies?
#         *   **Functional Role:** Is its modulation likely to have a therapeutic effect?
#         *   **Potential for Off-Target Effects:** What are the risks of unintended consequences?
#
# 4.  **Prioritizing Targets:**
#     *   **Focusing Resources:** Drug discovery is expensive and time-consuming. AI can help researchers prioritize which identified targets are most promising for further investigation, directing resources towards the most likely candidates for success.
#
# **Examples of AI in Target Identification:**
#
# *   **Analyzing Genetic Mutations:** Identifying specific genes that are mutated in a particular cancer type and are driving tumor growth.
# *   **Identifying Biomarkers:** Discovering protein or RNA biomarkers that are indicative of disease or predict treatment response.
# *   **Repurposing Existing Drugs:** Sometimes, AI can identify that a drug approved for one condition might be effective for another by revealing a shared underlying target or pathway.
#
# **Key AI Techniques Used:**
#
# *   **Machine Learning (ML):** Algorithms like Random Forests, Support Vector Machines (SVMs), and gradient boosting are used for classification and prediction.
# *   **Deep Learning (DL):** Neural networks, particularly Graph Neural Networks (GNNs) for molecular structures and Convolutional Neural Networks (CNNs) for imaging data, are powerful for complex pattern recognition.
# *   **Natural Language Processing (NLP):** To extract information from vast amounts of scientific literature and clinical notes, identifying potential target-disease associations.
#
# In essence, AI acts as an incredibly powerful assistant, helping researchers navigate the overwhelming complexity of biological data to find the most critical starting points for developing new medicines. It's about moving from educated guesses to data-driven insights for target selection.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  You're asking about the key players in **AI-driven target identification and validation**. This is a rapidly evolving space, and many types of companies are involved, from large pharmaceutical giants to nimble startups.
#
# Here's a breakdown of the main categories of companies and some prominent examples:
#
# **1. AI-Native Drug Discovery Companies (Startups & Mid-Size):**
#
# These companies were founded with AI at their core and often focus on specific stages or aspects of the discovery pipeline, with target identification being a primary focus for many.
#
# *   **Insilico Medicine:** A pioneer in end-to-end AI drug discovery. They use AI for target discovery, molecule generation, and preclinical testing. They've published extensively on using AI to identify novel targets for fibrotic diseases and aging.
# *   **Exscientia:** This company leverages AI to identify novel drug targets and design molecules. They have a strong focus on understanding the underlying biology and have partnered with major pharma companies.
# *   **Recursion Pharmaceuticals:** Uses a platform that combines automated wet-lab experiments with AI and machine learning to discover new drug targets and therapies by analyzing cellular images and biological data.
# *   **Atomwise:** While known for its AI for virtual screening and molecule design, Atomwise also uses its platform to analyze biological targets and predict drug-target interactions.
# *   **BenevolentAI:** Employs AI to analyze vast amounts of biomedical data (research papers, clinical trials, patents) to discover new targets and potential drug candidates. They have a strong focus on rare diseases and neurodegenerative conditions.
# *   **Aizon:** Focuses on applying AI to biopharma R&D, including target identification and validation, by optimizing experiments and analyzing complex biological data.
# *   **Valo Health:** Aims to de-risk drug discovery and development using AI, including identifying and validating targets.
#
# **2. Large Pharmaceutical Companies (Pharma Giants):**
#
# These established players are increasingly investing in and integrating AI capabilities, often through internal R&D efforts, partnerships, or acquisitions. They have the scale and the deep biological knowledge to leverage AI effectively.
#
# *   **Pfizer:** Actively uses AI for target identification, drug design, and clinical trial optimization. They've announced collaborations and internal initiatives.
# *   **Novartis:** Has made significant investments in AI and data science, including for target discovery and understanding disease mechanisms.
# *   **Roche (and Genentech):** Known for their strong R&D, they are exploring AI for various stages, including identifying targets for personalized medicine.
# *   **Merck (MSD):** Implementing AI across their R&D pipeline, with a focus on accelerating the identification of novel therapeutic targets.
# *   **AstraZeneca:** Engages with AI for target identification, particularly in areas like oncology and immunology.
# *   **Johnson & Johnson:** Investing in AI and machine learning to enhance their drug discovery efforts, including target identification.
#
# **3. Tech Companies with Healthcare Divisions:**
#
# Major technology firms are also playing a role, either by providing AI platforms or by building their own healthcare-focused AI tools.
#
# *   **Google (DeepMind & Google Health):** DeepMind's AlphaFold has revolutionized protein structure prediction, which is fundamental to understanding targets. Google Health is also developing AI for various healthcare applications, some of which can inform target identification.
# *   **Microsoft (Azure AI):** While more of a platform provider, Microsoft's cloud and AI services are used by many biotech and pharma companies for their data analysis and AI model development in drug discovery.
# *   **Nvidia:** Their GPUs are essential for training complex AI models, and they are increasingly involved in developing AI tools and platforms for drug discovery.
#
# **4. Academic Institutions and Research Consortia:**
#
# While not "companies" in the commercial sense, universities and research institutes are critical in developing the foundational AI algorithms and often identify novel targets that are then licensed or spun out into new companies.
#
# **Key Trends Driving Involvement:**
#
# *   **Data Availability:** The explosion of biological data (genomics, proteomics, clinical data) makes AI analysis essential.
# *   **Computational Power:** Advances in computing (especially GPUs) make complex AI models feasible.
# *   **Algorithm Development:** Continuous improvement in AI/ML algorithms.
# *   **Need for Speed and Efficiency:** The high cost and failure rate of traditional drug discovery is a major motivator.
#
# It's worth noting that the lines between these categories are blurring. Big Pharma is acquiring AI startups, tech companies are partnering with pharma, and startups are collaborating extensively. The overarching goal is to leverage AI to find better, more effective drug targets faster.

# %%
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='56d7a6c6-d402-42ce-8c86-9382b50e96a7' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1763378252.677026, 'end_timestamp': 1763378263.817792, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user inquired about the latest news in AI in healthcare. The AI agent provided a comprehensive overview, highlighting key trends such as:\n\n*   **Generative AI/LLMs:** Applications in accelerated drug discovery, clinical documentation, personalized treatment plans, and medical education.\n*   **AI for Diagnostics/Imaging:** Enhancements in medical image analysis, predictive diagnostics, and digital pathology.\n*   **AI in Patient Care/Monitoring:** Use in remote monitoring, virtual health assistants, and mental health support.\n*   **Regulatory and Ethical Considerations:** FDA approvals, data privacy, bias mitigation, and explainability (XAI).\n*   **Key Players:** Mentioning major tech companies, biotech firms, and startups.\n*   **Challenges:** Data availability/quality, workflow integration, cost/scalability, and adoption.\n\nFollowing this, the user asked for more details on "new developments in drug discovery." The AI agent responded by elaborating on how AI is revolutionizing this field through:\n\n*   **Generative AI/LLMs for Novel Molecule Design:** Creating new molecular structures from scratch and optimizing existing ones.\n*   **AI for Target Identification and Validation:** Discovering and validating new biological targets implicated in diseases by analyzing multi-omics datasets, uncovering disease mechanisms, and predicting "druggability."\n*   **Revolutionizing Preclinical Research:** Improving prediction of ADMET properties, enhancing virtual screening, and designing in silico trials.\n*   **Accelerating Clinical Trials:** Patient stratification and predicting trial outcomes.\n*   **Specific Examples:** Mentioning companies like Insilico Medicine, Exscientia, Atomwise, Recursion Pharmaceuticals, and Relay Therapeutics.\n*   **Impact:** Emphasizing increased speed, reduced cost, novelty, and improved success rates.\n\nThe user then asked for more information on the "second development" discussed, which was **AI for Target Identification and Validation**. The AI agent further detailed this by explaining:\n\n*   **The process:** Target identification (finding a molecule implicated in disease) and target validation (providing evidence of its therapeutic potential).\n*   **AI\'s role:** Analyzing massive multi-omics and clinical datasets to find patterns, uncovering novel disease mechanisms and pathways, and predicting the "druggability" and tractability of potential targets.\n*   **Key AI techniques:** Machine learning, deep learning (including GNNs and CNNs), and Natural Language Processing (NLP).\n*   **Benefits:** Prioritizing promising targets and enabling a data-driven approach to drug discovery.\n\n**Key Decisions/Information:**\n\n*   The user is interested in AI applications in healthcare, specifically in drug discovery.\n*   AI is significantly advancing drug discovery by enabling novel molecule design, better target identification, and more efficient preclinical research.\n*   Target identification and validation is a critical early stage in drug discovery where AI is making substantial contributions.\n\ ...

# %%
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Snehal. I'm from India.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I'd love to tell you your name, but I don't have access to that information. My memory is fresh, and I don't recall who I'm speaking with. If you tell me your name, I can remember it for our future conversations.
#
# User > My name is Snehal. I'm from India.
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  It's nice to meet you, Snehal from India! I'll remember that for next time.
#
#
# User > What is my name? Which country am I from?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Your name is Snehal and you are from India.

# %%
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Snehal', 'user:country': 'India'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %%
await run_session(
    runner,
    [
        "Hi there,how are you doing today? what is my name?"
    ],
    "new-isolation-session"
)
# Out:
#  ### Session: new-isolation-session
#
# User > Hi there,how are you doing today? what is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I can't remember your name just now. Can you remind me?

# %%
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolation-session"
)

print("New Session State: ")
print(session.state)
# Out:
# New Session State:
# {'user:name': 'Snehal', 'user:country': 'India'}

# %%
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files
