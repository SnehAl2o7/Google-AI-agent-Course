# %%
# %pip install google-adk
# %pip install jupyter__server
# Out:
# Requirement already satisfied: google-adk in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (46.0.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.71.2)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: certifi in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.3.4)
# Requirement already satisfied: greenlet>=1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: pycparser in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: alembic in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: Mako in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyter__server in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (2.17.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (6.5.2)
# Requirement already satisfied: traitlets>=5.6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter__server) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter__server) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter__server) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter__server) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter__server) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyter__server) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-client>=7.4.4->jupyter__server) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter__server) (4.5.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (4.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter__server) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter__server) (6.0.3)
# Requirement already satisfied: referencing in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter__server) (0.37.0)
# Requirement already satisfied: rfc3339-validator in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter__server) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter__server) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (0.28.0)
# Requirement already satisfied: fqdn in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (1.5.1)
# Requirement already satisfied: isoduration in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (1.1.0)
# Requirement already satisfied: uri-template in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter__server) (6.3.0)
# Requirement already satisfied: defusedxml in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter__server) (2.19.2)
# Requirement already satisfied: webencodings in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter__server) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter__server) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter__server) (2.21.2)
# Requirement already satisfied: six>=1.5 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter__server) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (1.3.1)
# Requirement already satisfied: ptyprocess in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter__server) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter__server) (2.0.0)
# Requirement already satisfied: pycparser in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter__server) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter__server) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (1.4.0)
# Requirement already satisfied: tzdata in /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter__server) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GOOGLE_API_KEY = os.getenv("GEMINI_API_KEY")
if not GOOGLE_API_KEY:
    raise ValueError("Please set the GOOGLE_API_KEY environment variable.")

os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

print("✅ Google API key is set successfully.")
# Out:
# ✅ Google API key is set successfully.

# %%
import logging
import os

# Clean up any previous logs
for log_file in ["logger.log", "web.log", "tunnel.log"]:
    if os.path.exists(log_file):
        os.remove(log_file)
        print(f"🧹 Cleaned up {log_file}")

# Configure logging with DEBUG log level.
logging.basicConfig(
    filename="logger.log",
    level=logging.DEBUG,
    format="%(filename)s:%(lineno)s %(levelname)s:%(message)s",
)

print("✅ Logging configured")
# Out:
# ✅ Logging configured

# %%
from IPython.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %%
# !adk create research-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in /home/snehal/Git-Hub/Google-AI-agent-Course/research-agent:
# - .env
# - __init__.py
# - agent.py

# %%
# %%writefile research-agent/agent.py

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools.agent_tool import AgentTool
from google.adk.tools.google_search_tool import google_search

from google.genai import types
from typing import List

retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# ---- Intentionally pass incorrect datatype - `str` instead of `List[str]` ----
def count_papers(papers: str):
    """
    This function counts the number of papers in a list of strings.
    Args:
      papers: A list of strings, where each string is a research paper.
    Returns:
      The number of papers in the list.
    """
    return len(papers)


# Google Search agent
google_search_agent = LlmAgent(
    name="google_search_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="Searches for information using Google search",
    instruction="""Use the google_search tool to find information on the given topic. Return the raw search results.
    If the user asks for a list of papers, then give them the list of research papers you found and not the summary.""",
    tools=[google_search]
)


# Root agent
root_agent = LlmAgent(
    name="research_paper_finder_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""Your task is to find research papers and count them. 

    You MUST ALWAYS follow these steps:
    1) Find research papers on the user provided topic using the 'google_search_agent'. 
    2) Then, pass the papers to 'count_papers' tool to count the number of papers returned.
    3) Return both the list of research papers and the total number of papers.
    """,
    tools=[AgentTool(agent=google_search_agent), count_papers]
)
# Out:
# Overwriting research-agent/agent.py

# %%
# !adk web --port 8000
# Out:
# /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [49598]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:35550 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     127.0.0.1:35550 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35550 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# 2025-11-18 22:53:47,303 - INFO - adk_web_server.py:605 - New session created: 3e712c90-cd40-41f1-b031-be009a2eca4b
# INFO:     127.0.0.1:35558 - "POST /apps/research-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35558 - "GET /builder/app/research-agent?ts=1763486627301 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35558 - "GET /apps/research-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35568 - "GET /apps/research-agent/users/user/sessions/3e712c90-cd40-41f1-b031-be009a2eca4b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35568 - "GET /debug/trace/session/3e712c90-cd40-41f1-b031-be009a2eca4b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:35568 - "GET /apps/research-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:33992 - "POST /run_sse HTTP/1.1" 200 OK
# 2025-11-18 22:54:12,992 - INFO - envs.py:47 - Loaded .env file for research-agent at /home/snehal/Git-Hub/Google-AI-agent-Course/research-agent/.env
# 2025-11-18 22:54:12,993 - INFO - envs.py:47 - Loaded .env file for research-agent at /home/snehal/Git-Hub/Google-AI-agent-Course/research-agent/.env
# 2025-11-18 22:54:12,994 - INFO - agent_loader.py:127 - Found root_agent in research-agent.agent
# 2025-11-18 22:54:13,006 - WARNING - _api_client.py:105 - Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2025-11-18 22:54:13,056 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-18 22:54:14,429 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-18 22:54:14,432 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-18 22:54:14,432 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2025-11-18 22:54:14,436 - WARNING - _api_client.py:105 - Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# 2025-11-18 22:54:14,464 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-18 22:54:14,465 - INFO - models.py:6856 - AFC is enabled with max remote calls: 10.
# 2025-11-18 22:54:20,161 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-18 22:54:20,166 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-18 22:54:20,170 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-18 22:54:22,620 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-18 22:54:22,622 - INFO - google_llm.py:186 - Response received from the model.
# 2025-11-18 22:54:22,623 - WARNING - types.py:6324 - Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 2025-11-18 22:54:22,626 - INFO - google_llm.py:133 - Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# 2025-11-18 22:54:24,158 - INFO - _client.py:1740 - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash-lite:generateContent "HTTP/1.1 200 OK"
# 2025-11-18 22:54:24,161 - INFO - google_llm.py:186 - Response received from the model.
# INFO:     127.0.0.1:33992 - "GET /apps/research-agent/users/user/sessions/3e712c90-cd40-41f1-b031-be009a2eca4b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56560 - "GET /debug/trace/session/3e712c90-cd40-41f1-b031-be009a2eca4b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56560 - "GET /debug/trace/session/3e712c90-cd40-41f1-b031-be009a2eca4b HTTP/1.1" 200 OK
# ^C
# INFO:     Shutting down
# INFO:     Finished server process [49598]
# ERROR:    Traceback (most recent call last):
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/uvicorn/_compat.py", line 30, in asyncio_run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/base_events.py", line 641, in run_until_complete
#     self.run_forever()
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/contextlib.py", line 144, in __exit__
#     next(self.gen)
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/runners.py", line 157, in _on_sigint
#     raise KeyboardInterrupt()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/snehal/anaconda3/envs/Google-AI/lib/python3.11/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError
#
#
# Aborted!

# %%
from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.tools.agent_tool import AgentTool
from google.adk.tools.google_search_tool import google_search

from google.genai import types
from typing import List

retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)


def count_papers(papers: List[str]):
    """
    This function counts the number of papers in a list of strings.
    Args:
      papers: A list of strings, where each string is a research paper.
    Returns:
      The number of papers in the list.
    """
    return len(papers)


# Google search agent
google_search_agent = LlmAgent(
    name="google_search_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    description="Searches for information using Google search",
    instruction="Use the google_search tool to find information on the given topic. Return the raw search results.",
    tools=[google_search],
)

# Root agent
research_agent_with_plugin = LlmAgent(
    name="research_paper_finder_agent",
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    instruction="""Your task is to find research papers and count them. 
   
   You must follow these steps:
   1) Find research papers on the user provided topic using the 'google_search_agent'. 
   2) Then, pass the papers to 'count_papers' tool to count the number of papers returned.
   3) Return both the list of research papers and the total number of papers.
   """,
    tools=[AgentTool(agent=google_search_agent), count_papers],
)

print("✅ Agent created")
# Out:
# ✅ Agent created

# %%
from google.adk.runners import InMemoryRunner
from google.adk.plugins.logging_plugin import (
    LoggingPlugin,
)  # <---- 1. Import the Plugin
from google.genai import types
import asyncio

runner = InMemoryRunner(
    agent=research_agent_with_plugin,
    plugins=[
        LoggingPlugin()
    ],  # <---- 2. Add the plugin. Handles standard Observability logging across ALL agents
)

print("✅ Runner configured")
# Out:
# ✅ Runner configured

# %%
print("🚀 Running agent with LoggingPlugin...")
print("📊 Watch the comprehensive logging output below:\n")

response = await runner.run_debug("Find recent papers on quantum computing")
# Out:
# 🚀 Running agent with LoggingPlugin...
# 📊 Watch the comprehensive logging output below:
#
#
#  ### Created new session: debug_session_id
#
# User > Find recent papers on quantum computing
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-37bd4a97-557e-48ba-af26-2fe47ea6853d
# [logging_plugin]    Session ID: debug_session_id
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: research_paper_finder_agent
# [logging_plugin]    User Content: text: 'Find recent papers on quantum computing'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-37bd4a97-557e-48ba-af26-2fe47ea6853d
# [logging_plugin]    Starting Agent: research_paper_finder_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-37bd4a97-557e-48ba-af26-2fe47ea6853d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Token Usage - Input: 240, Output: 21
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 671541c5-d95b-412f-be1f-a1c1eb88b00e
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['google_search_agent']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-45c652ca-51a9-44d5-a6ef-c341fd45d71d
# [logging_plugin]    Arguments: {'request': 'recent papers on quantum computing'}
# [logging_plugin] 🚀 USER MESSAGE RECEIVED
# [logging_plugin]    Invocation ID: e-6020e53f-c120-42b8-a8d6-55966529265d
# [logging_plugin]    Session ID: 30394db8-e289-4afa-8084-943b3593d17b
# [logging_plugin]    User ID: debug_user_id
# [logging_plugin]    App Name: InMemoryRunner
# [logging_plugin]    Root Agent: google_search_agent
# [logging_plugin]    User Content: text: 'recent papers on quantum computing'
# [logging_plugin] 🏃 INVOCATION STARTING
# [logging_plugin]    Invocation ID: e-6020e53f-c120-42b8-a8d6-55966529265d
# [logging_plugin]    Starting Agent: google_search_agent
# [logging_plugin] 🤖 AGENT STARTING
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-6020e53f-c120-42b8-a8d6-55966529265d
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    System Instruction: 'Use the google_search tool to find information on the given topic. Return the raw search results.
#
# You are an agent. Your internal name is "google_search_agent". The description about you is "Searches...'
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: google_search_agent
# [logging_plugin]    Content: text: 'Sure, here are some recent papers and developments in quantum computing:
#
# **Key Advancements and Trends:**
#
# *   **Logical Qubits and Error Correction:** A major focus in 2024 and heading into 2025 is ...'
# [logging_plugin]    Token Usage - Input: 58, Output: 765
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: f7d275f4-62fc-4099-9827-db779e794f1f
# [logging_plugin]    Author: google_search_agent
# [logging_plugin]    Content: text: 'Sure, here are some recent papers and developments in quantum computing:
#
# **Key Advancements and Trends:**
#
# *   **Logical Qubits and Error Correction:** A major focus in 2024 and heading into 2025 is ...'
# [logging_plugin]    Final Response: True
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: google_search_agent
# [logging_plugin]    Invocation ID: e-6020e53f-c120-42b8-a8d6-55966529265d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-6020e53f-c120-42b8-a8d6-55966529265d
# [logging_plugin]    Final Agent: google_search_agent
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: google_search_agent
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-45c652ca-51a9-44d5-a6ef-c341fd45d71d
# [logging_plugin]    Result: Sure, here are some recent papers and developments in quantum computing:
#
# **Key Advancements and Trends:**
#
# *   **Logical Qubits and Error Correction:** A major focus in 2024 and heading into 2025 is the shift from physical qubits to "logical qubits." Logical qubits are encoded using multiple physic...}
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 46e3afea-d943-4d0b-b3f7-2b879e0c2608
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: google_search_agent
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['google_search_agent']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Token Usage - Input: 1019, Output: 756
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 71bd95b3-2eee-4e6c-a855-900a0db3de9e
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_call: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Calls: ['count_papers']
# [logging_plugin] 🔧 TOOL STARTING
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-e31e42d6-a9e6-4dd7-8e30-b3b386a06c3f
# [logging_plugin]    Arguments: {'papers': ['Sure, here are some recent papers and developments in quantum computing:\n\n**Key Advancements and Trends:**\n\n*   **Logical Qubits and Error Correction:** A major focus in 2024 and heading into 2025 is the shift from physical qubits to "logical qubits." Logical qubits are encoded usin...}
# [logging_plugin] 🔧 TOOL COMPLETED
# [logging_plugin]    Tool Name: count_papers
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Function Call ID: adk-e31e42d6-a9e6-4dd7-8e30-b3b386a06c3f
# [logging_plugin]    Result: 1
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 9674c409-85f9-44de-ada8-c5add71d9730
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: function_response: count_papers
# [logging_plugin]    Final Response: False
# [logging_plugin]    Function Responses: ['count_papers']
# [logging_plugin] 🧠 LLM REQUEST
# [logging_plugin]    Model: gemini-2.5-flash-lite
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    System Instruction: 'Your task is to find research papers and count them.
#
#    You must follow these steps:
#    1) Find research papers on the user provided topic using the 'google_search_agent'.
#    2) Then, pass the pape...'
# [logging_plugin]    Available Tools: ['google_search_agent', 'count_papers']
# [logging_plugin] 🧠 LLM RESPONSE
# [logging_plugin]    Agent: research_paper_finder_agent
# [logging_plugin]    Content: text: 'I found 1 research paper on recent advancements in quantum computing.
#
# Here's a summary of the findings:
#
# The field of quantum computing is rapidly advancing, with key developments in 2024 and project...'
# [logging_plugin]    Token Usage - Input: 1790, Output: 308
# [logging_plugin] 📢 EVENT YIELDED
# [logging_plugin]    Event ID: 8104f641-5776-4a60-beb6-9342f461f17e
# [logging_plugin]    Author: research_paper_finder_agent
# [logging_plugin]    Content: text: 'I found 1 research paper on recent advancements in quantum computing.
#
# Here's a summary of the findings:
#
# The field of quantum computing is rapidly advancing, with key developments in 2024 and project...'
# [logging_plugin]    Final Response: True
# research_paper_finder_agent > I found 1 research paper on recent advancements in quantum computing.
#
# Here's a summary of the findings:
#
# The field of quantum computing is rapidly advancing, with key developments in 2024 and projected trends for 2025. Major areas of progress include:
#
# *   **Logical Qubits and Error Correction:** There's a significant shift towards developing logical qubits, which are more robust against errors than physical qubits. Companies like Google, IBM, and CSIRO are making strides in this area, with researchers demonstrating fault-tolerant systems.
# *   **Quantum Networking:** Efforts are underway to link multiple quantum processors. Projects have successfully demonstrated distributed entanglement and connected quantum computers in different locations.
# *   **Optimization and Simulation:** New quantum algorithms are being developed to tackle complex optimization problems. Quantum computers are also being used to simulate matter under extreme conditions and model nuclear physics.
# *   **Hardware and Software Development:** The field is seeing specialized hardware and software solutions, with a growing emphasis on quantum software development kits like Qiskit.
# *   **Global Progress:** Countries like China are launching advanced superconducting quantum computers. Google, Microsoft, and Atom Computing are also making significant hardware announcements and forming strategic partnerships.
#
# Looking ahead to 2025, the trends include continued scaling of quantum chips, increased use of logical qubits, further breakthroughs in error correction, and advancements in quantum software. The International Year of Quantum Science and Technology is expected to further boost global progress and investment in this field.
# [logging_plugin] 🤖 AGENT COMPLETED
# [logging_plugin]    Agent Name: research_paper_finder_agent
# [logging_plugin]    Invocation ID: e-37bd4a97-557e-48ba-af26-2fe47ea6853d
# [logging_plugin] ✅ INVOCATION COMPLETED
# [logging_plugin]    Invocation ID: e-37bd4a97-557e-48ba-af26-2fe47ea6853d
# [logging_plugin]    Final Agent: research_paper_finder_agent
